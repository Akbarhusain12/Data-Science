# %%
import pandas as pd

# %%
df = pd.read_csv('Files/seed_data.csv')

# %%
df
# Out:
#       Area  Perimeter  Compactness  Kernel Length  Kernel Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 205  12.19      13.20       0.8783          5.137         2.981
# 206  11.23      12.88       0.8511          5.140         2.795
# 207  13.20      13.66       0.8883          5.236         3.232
# 208  11.84      13.21       0.8521          5.175         2.836
# 209  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry Coefficient  Groove Length     Class
# 0                    2.221          5.220      Kama
# 1                    1.018          4.956      Kama
# ...

# %%
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel Length  Kernel Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry Coefficient  Groove Length Class
# 0                  2.221          5.220  Kama
# 1                  1.018          4.956  Kama
# 2                  2.699          4.825  Kama
# 3                  2.259          4.805  Kama
# 4                  1.355          5.175  Kama

# %%
df.isnull().sum()
# Out:
# Area                     0
# Perimeter                0
# Compactness              0
# Kernel Length            0
# Kernel Width             0
# Asymmetry Coefficient    0
# Groove Length            0
# Class                    0
# dtype: int64

# %% [markdown]
# ##  Which wheat variety has the highest "Area"?

# %%
print(df[['Area','Class']])
# Out:
#       Area     Class
# 0    15.26      Kama
# 1    14.88      Kama
# 2    14.29      Kama
# 3    13.84      Kama
# 4    16.14      Kama
# ..     ...       ...
# 205  12.19  Canadian
# 206  11.23  Canadian
# 207  13.20  Canadian
# 208  11.84  Canadian
# 209  12.30  Canadian
#
# [210 rows x 2 columns]

# %%
max_index = df['Area'].max()
print(max_area_index)
highest_area_variety = df.iloc[max_area_index, 'Class']
# Out:
# 21.18
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\Python312\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File C:\Python312\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 max_area_index = df['Area'].max()
# ...
